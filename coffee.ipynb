# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress
from sklearn import datasets

from pathlib import Path
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report

# Study data files
coffee_path = "GACTT_RESULTS_ANONYMIZED_v2.csv"

# Read data
coffee_data = pd.read_csv(coffee_path)

# Make a DataFrame
origin_coffee_df = pd.DataFrame(coffee_data)

# Display the data table for preview
origin_coffee_df.sample(10)
# Out:
#      Submission ID What is your age?  \
# 3602        42PN8B   25-34 years old
# 1807        aBrMLB   25-34 years old
# 3261        Rz8GXv   25-34 years old
# 344         BGbJ9Q   25-34 years old
# 1926        zKQ9ME   55-64 years old
# 3378        oAlD8M   25-34 years old
# 295         g5N8pl   25-34 years old
# 3014        1rbjQ4   18-24 years old
# 3027        RzZp4P   25-34 years old
# 671         24xGAj   25-34 years old
#
#      How many cups of coffee do you typically drink per day?  \
# 3602                                                  3
# 1807                                                  1
# 3261                                        Less than 1
# 344                                                   2
# 1926                                                  1
# 3378                                        Less than 1
# 295                                                   2
# 3014                                                  1
# 3027                                                  1
# 671                                                   2
#
#               Where do you typically drink coffee?  \
# 3602                                       At home
# 1807                                       At home
# 3261                          On the go, At a cafe
# 344   At the office, At a cafe, At home, On the go
# 1926                                 At the office
# 3378                                 None of these
# 295                         At the office, At home
# 3014                                       At home
# 3027                            At home, At a cafe
# 671                             At home, At a cafe
#
#      Where do you typically drink coffee? (At home)  \
# 3602                                           True
# 1807                                           True
# 3261                                          False
# 344                                            True
# 1926                                          False
# 3378                                          False
# 295                                            True
# 3014                                           True
# 3027                                           True
# 671                                            True
#
#      Where do you typically drink coffee? (At the office)  \
# 3602                                              False
# 1807                                              False
# 3261                                              False
# 344                                                True
# 1926                                               True
# 3378                                              False
# 295                                                True
# 3014                                              False
# 3027                                              False
# 671                                               False
#
#      Where do you typically drink coffee? (On the go)  \
# 3602                                            False
# 1807                                            False
# 3261                                             True
# 344                                              True
# 1926                                            False
# 3378                                            False
# 295                                             False
# 3014                                            False
# 3027                                            False
# 671                                             False
#
#      Where do you typically drink coffee? (At a cafe)  \
# 3602                                            False
# 1807                                            False
# 3261                                             True
# 344                                              True
# 1926                                            False
# 3378                                            False
# 295                                             False
# 3014                                            False
# 3027                                             True
# 671                                              True
#
#      Where do you typically drink coffee? (None of these)  \
# 3602                                              False
# 1807                                              False
# 3261                                              False
# 344                                               False
# 1926                                              False
# 3378                                               True
# 295                                               False
# 3014                                              False
# 3027                                              False
# 671                                               False
#
#                         How do you brew coffee at home?  ...  \
# 3602                                Pour over, Espresso  ...
# 1807           Coffee brewing machine (e.g. Mr. Coffee)  ...
# 3261                                                NaN  ...
# 344            Coffee brewing machine (e.g. Mr. Coffee)  ...
# 1926                                                NaN  ...
# 3378                                                NaN  ...
# 295                                           Pour over  ...
# 3014                                          Pour over  ...
# 3027  Pour over, Coffee brewing machine (e.g. Mr. Co...  ...
# 671                                    Pour over, Other  ...
#
#      Approximately how much have you spent on coffee equipment in the past 5 years?  \
# 3602                                          $300-$500
# 1807                                      Less than $20
# 3261                                            $20-$50
# 344                                             $20-$50
# 1926                                          $300-$500
# 3378                                      Less than $20
# 295                                           $300-$500
# 3014                                          $300-$500
# 3027                                   More than $1,000
# 671                                    More than $1,000
#
#      Do you feel like you’re getting good value for your money with regards to your coffee equipment?  \
# 3602                                                Yes
# 1807                                                Yes
# 3261                                                Yes
# 344                                                 Yes
# 1926                                                Yes
# 3378                                                Yes
# 295                                                 Yes
# 3014                                                 No
# 3027                                                 No
# 671                                                 Yes
#
#       Gender Gender (please specify)                     Education Level  \
# 3602    Male                     NaN    Doctorate or professional degree
# 1807  Female                     NaN  Some college or associate's degree
# 3261  Female                     NaN                   Bachelor's degree
# 344   Female                     NaN                     Master's degree
# 1926  Female                     NaN                   Bachelor's degree
# 3378    Male                     NaN                     Master's degree
# 295     Male                     NaN                                 NaN
# 3014    Male                     NaN  Some college or associate's degree
# 3027  Female                     NaN                   Bachelor's degree
# 671     Male                     NaN  Some college or associate's degree
#
#        Ethnicity/Race Ethnicity/Race (please specify)   Employment Status  \
# 3602  White/Caucasian                             NaN  Employed full-time
# 1807  Hispanic/Latino                             NaN  Employed full-time
# 3261  White/Caucasian                             NaN  Employed full-time
# 344   White/Caucasian                             NaN  Employed full-time
# 1926  White/Caucasian                             NaN  Employed full-time
# 3378  White/Caucasian                             NaN  Employed full-time
# 295               NaN                             NaN                 NaN
# 3014  White/Caucasian                             NaN             Student
# 3027              NaN                             NaN          Unemployed
# 671   White/Caucasian                             NaN  Employed full-time
#
#      Number of Children Political Affiliation
# 3602               None            Republican
# 1807                  1              Democrat
# 3261               None        No affiliation
# 344                None              Democrat
# 1926                  3        No affiliation
# 3378               None           Independent
# 295                 NaN                   NaN
# 3014               None              Democrat
# 3027               None              Democrat
# 671                None              Democrat
#
# [10 rows x 113 columns]

# %%
column_list =  pd.DataFrame(list(origin_coffee_df.columns.values))

print(column_list)
# Out:
#                                                      0
# 0                                        Submission ID
# 1                                    What is your age?
# 2    How many cups of coffee do you typically drink...
# 3                 Where do you typically drink coffee?
# 4       Where do you typically drink coffee? (At home)
# ..                                                 ...
# 108                                     Ethnicity/Race
# 109                    Ethnicity/Race (please specify)
# 110                                  Employment Status
# 111                                 Number of Children
# 112                              Political Affiliation
#
# [113 rows x 1 columns]

# %%
coffee_df = origin_coffee_df.drop(columns=['Submission ID', 'Ethnicity/Race (please specify)',
                                           'Gender (please specify)',
                                           'Political Affiliation'])

coffee_df = coffee_df.rename(columns={"What is your age?": "Age",
                          'How many cups of coffee do you typically drink per day?': 'Cups Per Day',
                          'Where do you typically drink coffee? (At home)': 'Typically Home?',
                          'Where do you typically drink coffee? (At the office)': 'Typically Office?',
                          'Where do you typically drink coffee? (At a cafe)': 'Typically at Cafe',
                          'Where do you typically drink coffee? (None of these)': 'None of These?',
                          'Where do you typically drink coffee? (On the go)': 'Typically on the go?',
                          'How do you brew coffee at home?': 'Brew Methods',
                          'How do you brew coffee at home? (Pour over)': 'Pour Over?',
                          "What is the most you've ever paid for a cup of coffee?":'Most Paid'})

# %%
coffee_df.sample(10)
# Out:
#                   Age Cups Per Day Where do you typically drink coffee?  \
# 3322  25-34 years old  Less than 1                              At home
# 1055  25-34 years old            1                   At a cafe, At home
# 1518  25-34 years old            1               At home, At the office
# 2004  35-44 years old            1               At the office, At home
# 1172  25-34 years old            2                              At home
# 3435  18-24 years old            1    At home, On the go, At the office
# 3931  45-54 years old  More than 4                              At home
# 3429  25-34 years old            2                   At a cafe, At home
# 27                NaN          NaN                                  NaN
# 498   25-34 years old            1                        At the office
#
#      Typically Home? Typically Office? Typically on the go? Typically at Cafe  \
# 3322            True             False                False             False
# 1055            True             False                False              True
# 1518            True              True                False             False
# 2004            True              True                False             False
# 1172            True             False                False             False
# 3435            True              True                 True             False
# 3931            True             False                False             False
# 3429            True             False                False              True
# 27             False             False                False             False
# 498            False              True                False             False
#
#      None of These?                                       Brew Methods  \
# 3322          False                              Instant coffee, Other
# 1055          False                                              Other
# 1518          False                                       French press
# 2004          False                                       French press
# 1172          False                                           Espresso
# 3435          False  French press, Espresso, Coffee brewing machine...
# 3931          False  Pour over, Coffee brewing machine (e.g. Mr. Co...
# 3429          False                                Pour over, Espresso
# 27            False                                                NaN
# 498           False                                                NaN
#
#      Pour Over?  ... Most Paid  \
# 3322      False  ...     $6-$8
# 1055      False  ...   $10-$15
# 1518      False  ...     $4-$6
# 2004      False  ...    $8-$10
# 1172      False  ...   $10-$15
# 3435      False  ...     $6-$8
# 3931       True  ...    $8-$10
# 3429       True  ...     $6-$8
# 27          NaN  ...       NaN
# 498         NaN  ...    $8-$10
#
#      What is the most you'd ever be willing to pay for a cup of coffee?  \
# 3322                                             $8-$10
# 1055                                             $8-$10
# 1518                                              $6-$8
# 2004                                            $10-$15
# 1172                                            $15-$20
# 3435                                             $8-$10
# 3931                                              $4-$6
# 3429                                            $10-$15
# 27                                                  NaN
# 498                                              $8-$10
#
#      Do you feel like you’re getting good value for your money when you buy coffee at a cafe?  \
# 3322                                                 No
# 1055                                                Yes
# 1518                                                 No
# 2004                                                 No
# 1172                                                Yes
# 3435                                                 No
# 3931                                                Yes
# 3429                                                 No
# 27                                                  NaN
# 498                                                 Yes
#
#      Approximately how much have you spent on coffee equipment in the past 5 years?  \
# 3322                                      Less than $20
# 1055                                           $50-$100
# 1518                                          $300-$500
# 2004                                          $100-$300
# 1172                                   More than $1,000
# 3435                                          $100-$300
# 3931                                   More than $1,000
# 3429                                          $300-$500
# 27                                                  NaN
# 498                                            $50-$100
#
#      Do you feel like you’re getting good value for your money with regards to your coffee equipment?  \
# 3322                                                Yes
# 1055                                                Yes
# 1518                                                Yes
# 2004                                                Yes
# 1172                                                Yes
# 3435                                                Yes
# 3931                                                Yes
# 3429                                                Yes
# 27                                                  NaN
# 498                                                 Yes
#
#           Gender                     Education Level          Ethnicity/Race  \
# 3322        Male                   Bachelor's degree  Other (please specify)
# 1055      Female                   Bachelor's degree         White/Caucasian
# 1518        Male                   Bachelor's degree         White/Caucasian
# 2004      Female                   Bachelor's degree         White/Caucasian
# 1172  Non-binary                   Bachelor's degree         White/Caucasian
# 3435      Female  Some college or associate's degree         Hispanic/Latino
# 3931        Male                High school graduate         White/Caucasian
# 3429        Male                   Bachelor's degree  Other (please specify)
# 27           NaN                                 NaN                     NaN
# 498       Female  Some college or associate's degree         White/Caucasian
#
#        Employment Status Number of Children
# 3322  Employed part-time               None
# 1055  Employed full-time               None
# 1518  Employed full-time               None
# 2004  Employed part-time               None
# 1172  Employed full-time               None
# 3435  Employed full-time               None
# 3931  Employed full-time                  3
# 3429  Employed part-time               None
# 27                   NaN                NaN
# 498   Employed full-time               None
#
# [10 rows x 109 columns]

# %%
coffee_column_list = pd.DataFrame(list(coffee_df.columns.values))

coffee_column_list.to_csv('coffee_columns.csv')

# %%
coffee_analysis_df = coffee_df[['Age', 'Cups Per Day', 'Where do you typically drink coffee?', 'Typically Home?', 
                                'Typically Office?', 'Typically on the go?', 'Typically at Cafe', 'Brew Methods', 'Pour Over?', 
                                'How do you brew coffee at home? (French press)', 'How do you brew coffee at home? (Espresso)', 
                                'How do you brew coffee at home? (Coffee brewing machine (e.g. Mr. Coffee))', 'How do you brew coffee at home? (Pod/capsule machine (e.g. Keurig/Nespresso))', 
                                'How do you brew coffee at home? (Instant coffee)', 'How do you brew coffee at home? (Bean-to-cup machine)', 
                                'How do you brew coffee at home? (Cold brew)', 
                                'How do you brew coffee at home? (Coffee extract (e.g. Cometeer))', 'How do you brew coffee at home? (Other)', 'What is your favorite coffee drink?', 
                                'How strong do you like your coffee?', 'What roast level of coffee do you prefer?', 'How much caffeine do you like in your coffee?', 
                                'Between Coffee A, Coffee B, and Coffee C which did you prefer?', 'Do you work from home or in person?', 'Why do you drink coffee?', 'Gender', 'Ethnicity/Race', 'Employment Status']].copy()

# %%
coffee_analysis_df = coffee_analysis_df.rename(columns={'How do you brew coffee at home? (French press)': 'French Press?',
                                   'How do you brew coffee at home? (Espresso)': 'Espresso?',
                                   'How do you brew coffee at home? (Coffee brewing machine (e.g. Mr. Coffee))': 'Mr. Coffee',
                                   'How do you brew coffee at home? (Pod/capsule machine (e.g. Keurig/Nespresso))': 'Pods',
                                   'How do you brew coffee at home? (Instant coffee)': 'Instant',
                                   'How do you brew coffee at home? (Bean-to-cup machine)': 'Bean to Cup',
                                   'How do you brew coffee at home? (Cold brew)': 'Cold Brew',
                                   'What is your favorite coffee drink?': 'Favorite Form',
                                   'How strong do you like your coffee?': 'Strength?',
                                   'What roast level of coffee do you prefer?': 'Roast Preference',
                                   'How much caffeine do you like in your coffee?': 'How Much Caffeine?',
                                   'Between Coffee A, Coffee B, and Coffee C which did you prefer?': 'A, B, C',
                                   'Do you work from home or in person?': 'WFH',
                                   'Why do you drink coffee?': 'Why'})

coffee_analysis_df = coffee_analysis_df.drop(columns=['How do you brew coffee at home? (Coffee extract (e.g. Cometeer))', 
                                                      'How do you brew coffee at home? (Other)'])

# %%
coffee_analysis_df.sample(10)
# Out:
#                   Age Cups Per Day  \
# 2227  18-24 years old            4
# 2522  35-44 years old            2
# 561   25-34 years old            1
# 2283  25-34 years old            2
# 2020  25-34 years old            2
# 2601  25-34 years old            1
# 1434  25-34 years old            1
# 3810  18-24 years old            1
# 2835  35-44 years old  Less than 1
# 1411  18-24 years old            2
#
#               Where do you typically drink coffee? Typically Home?  \
# 2227                                       At home            True
# 2522  At home, At the office, On the go, At a cafe            True
# 561                                        At home            True
# 2283                                       At home            True
# 2020                            At home, At a cafe            True
# 2601                                       At home            True
# 1434                                       At home            True
# 3810                                 At the office           False
# 2835                            At a cafe, At home            True
# 1411                                       At home            True
#
#      Typically Office? Typically on the go? Typically at Cafe  \
# 2227             False                False             False
# 2522              True                 True              True
# 561              False                False             False
# 2283             False                False             False
# 2020             False                False              True
# 2601             False                False             False
# 1434             False                False             False
# 3810              True                False             False
# 2835             False                False              True
# 1411             False                False             False
#
#                                            Brew Methods Pour Over?  \
# 2227                                          Pour over       True
# 2522          Pour over, French press, Cold brew, Other       True
# 561                                 Pour over, Espresso       True
# 2283  Coffee brewing machine (e.g. Mr. Coffee), Espr...      False
# 2020                                Pour over, Espresso       True
# 2601           Coffee brewing machine (e.g. Mr. Coffee)      False
# 1434          Pour over, Coffee extract (e.g. Cometeer)       True
# 3810                                                NaN        NaN
# 2835                                          Pour over       True
# 1411  Espresso, Pour over, French press, Coffee brew...       True
#
#      French Press?  ...                     Favorite Form        Strength?  \
# 2227         False  ...               Regular drip coffee  Somewhat strong
# 2522          True  ...                             Other  Somewhat strong
# 561          False  ...                          Espresso  Somewhat strong
# 2283         False  ...                           Cortado           Medium
# 2020         False  ...                        Cappuccino           Medium
# 2601         False  ...                         Americano  Somewhat strong
# 1434         False  ...                          Pourover           Medium
# 3810           NaN  ...                             Latte   Somewhat light
# 2835         False  ...  Blended drink (e.g. Frappuccino)  Somewhat strong
# 1411          True  ...                          Pourover           Medium
#
#      Roast Preference How Much Caffeine?   A, B, C  \
# 2227            Light      Full caffeine  Coffee B
# 2522           Medium          Half caff       NaN
# 561             Light      Full caffeine  Coffee A
# 2283           Medium      Full caffeine  Coffee C
# 2020            Light      Full caffeine  Coffee A
# 2601           Medium      Full caffeine  Coffee C
# 1434            Light      Full caffeine  Coffee A
# 3810            Light              Decaf  Coffee B
# 2835            Light      Full caffeine  Coffee A
# 1411           Medium      Full caffeine  Coffee A
#
#                              WFH  \
# 2227          I do a mix of both
# 2522                         NaN
# 561   I primarily work from home
# 2283          I do a mix of both
# 2020  I primarily work from home
# 2601  I primarily work in person
# 1434  I primarily work from home
# 3810          I do a mix of both
# 2835  I primarily work in person
# 1411          I do a mix of both
#
#                                                     Why  \
# 2227  It tastes good, I need the caffeine, I need th...
# 2522                                                NaN
# 561                   It tastes good, I need the ritual
# 2283                                     It tastes good
# 2020  It tastes good, I need the caffeine, I need th...
# 2601                                     It tastes good
# 1434                                     It tastes good
# 3810                                     It tastes good
# 2835                                     It tastes good
# 1411                  It tastes good, I need the ritual
#
#                       Gender   Ethnicity/Race   Employment Status
# 2227  Other (please specify)  White/Caucasian  Employed full-time
# 2522                     NaN              NaN                 NaN
# 561                     Male  White/Caucasian  Employed full-time
# 2283                  Female  White/Caucasian  Employed full-time
# 2020                    Male  White/Caucasian  Employed full-time
# 2601                    Male  White/Caucasian  Employed full-time
# 1434                  Female  White/Caucasian  Employed part-time
# 3810                  Female              NaN  Employed full-time
# 2835                  Female  White/Caucasian  Employed part-time
# 1411                    Male  White/Caucasian  Employed full-time
#
# [10 rows x 26 columns]

# %%
coffee_Analysis_column_list = pd.DataFrame(list(coffee_analysis_df.columns.values))

coffee_Analysis_column_list.to_csv('coffee_analysis_df.csv')

# %%
wfh_df = coffee_analysis_df[['Age', 'WFH', 'Cups Per Day', 'Brew Methods', 'Strength?', 'How Much Caffeine?', 'Why', 'Favorite Form']].copy()

wfh_df.sample(10)
# Out:
#                   Age                         WFH Cups Per Day  \
# 2125  45-54 years old  I primarily work in person            3
# 1869  25-34 years old  I primarily work from home            2
# 1150  25-34 years old  I primarily work in person            1
# 3280  25-34 years old  I primarily work from home  Less than 1
# 1875  35-44 years old  I primarily work in person            1
# 922   35-44 years old  I primarily work from home            1
# 3866  25-34 years old  I primarily work in person            2
# 2323  35-44 years old  I primarily work from home            1
# 2598  25-34 years old  I primarily work in person            3
# 710   25-34 years old          I do a mix of both            3
#
#                                            Brew Methods        Strength?  \
# 2125           Coffee brewing machine (e.g. Mr. Coffee)  Somewhat strong
# 1869                                Espresso, Pour over  Somewhat strong
# 1150    Coffee brewing machine (e.g. Mr. Coffee), Other  Somewhat strong
# 3280                     Pour over, Espresso, Cold brew      Very strong
# 1875                                          Cold brew           Medium
# 922                                            Espresso           Medium
# 3866                                Pour over, Espresso  Somewhat strong
# 2323                                              Other      Very strong
# 2598  Pour over, Espresso, Coffee extract (e.g. Come...  Somewhat strong
# 710                                 Pour over, Espresso  Somewhat strong
#
#      How Much Caffeine?                                                Why  \
# 2125      Full caffeine                  It tastes good, I need the ritual
# 1869      Full caffeine  It tastes good, I need the caffeine, I need th...
# 1150      Full caffeine                                     It tastes good
# 3280      Full caffeine                                     It tastes good
# 1875      Full caffeine                                     It tastes good
# 922       Full caffeine  It tastes good, I need the caffeine, It makes ...
# 3866      Full caffeine  It tastes good, I need the caffeine, I need th...
# 2323      Full caffeine  It tastes good, I need the caffeine, I need th...
# 2598      Full caffeine  It tastes good, I need the caffeine, I need th...
# 710       Full caffeine  It tastes good, I need the caffeine, I need th...
#
#                          Favorite Form
# 2125                         Americano
# 1869                          Espresso
# 1150                        Cappuccino
# 3280                             Latte
# 1875  Blended drink (e.g. Frappuccino)
# 922                              Latte
# 3866               Regular drip coffee
# 2323                           Cortado
# 2598                          Pourover
# 710                          Americano

# %%
wfh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4042 entries, 0 to 4041
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 4011 non-null   object
#  1   WFH                 3524 non-null   object
#  2   Cups Per Day        3949 non-null   object
#  3   Brew Methods        3657 non-null   object
#  4   Strength?           3916 non-null   object
#  5   How Much Caffeine?  3917 non-null   object
#  6   Why                 3568 non-null   object
#  7   Favorite Form       3980 non-null   object
# dtypes: object(8)
# memory usage: 252.8+ KB

# %%
#Drop NaN rows, we want complete results

wfh_nona_df = wfh_df.dropna()

# %%
#Values of cups "more than 4" will be labeled as 5 in our dataset, and less than one will be labled as zero, less than 1 cup so they have had zero full cups 

wfh_nona_df['Cups Per Day'] = wfh_nona_df['Cups Per Day'].str.replace('More than 4', '5')
wfh_nona_df['Cups Per Day'] = wfh_nona_df['Cups Per Day'].str.replace('Less than 1', '0')
# Out:
# /var/folders/p2/2sz238yx2tjcxrfl2qyhd9980000gn/T/ipykernel_44037/2204697353.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wfh_nona_df['Cups Per Day'] = wfh_nona_df['Cups Per Day'].str.replace('More than 4', '5')
# /var/folders/p2/2sz238yx2tjcxrfl2qyhd9980000gn/T/ipykernel_44037/2204697353.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wfh_nona_df['Cups Per Day'] = wfh_nona_df['Cups Per Day'].str.replace('Less than 1', '0')

# %%
wfh_nona_df['Cups Per Day'] = pd.to_numeric(wfh_nona_df['Cups Per Day'], errors='raise')

wfh_nona_df = wfh_nona_df.dropna()

display(wfh_nona_df.sample(10))
display(wfh_nona_df.info())
# Out:
# /var/folders/p2/2sz238yx2tjcxrfl2qyhd9980000gn/T/ipykernel_44037/3440655689.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wfh_nona_df['Cups Per Day'] = pd.to_numeric(wfh_nona_df['Cups Per Day'], errors='raise')
#                   Age                         WFH  Cups Per Day  \
# 1321  55-64 years old  I primarily work in person             2
# 2845  25-34 years old          I do a mix of both             2
# 1596  45-54 years old  I primarily work from home             2
# 380   45-54 years old          I do a mix of both             3
# 862   25-34 years old  I primarily work from home             0
# 2758  25-34 years old  I primarily work from home             2
# 3097  35-44 years old  I primarily work from home             2
# 1329  25-34 years old  I primarily work in person             2
# 3320  35-44 years old  I primarily work from home             2
# 3593  25-34 years old  I primarily work from home             0
#
#                                            Brew Methods        Strength?  \
# 1321  French press, Coffee brewing machine (e.g. Mr....           Medium
# 2845                                          Pour over  Somewhat strong
# 1596           Coffee brewing machine (e.g. Mr. Coffee)           Medium
# 380   Pod/capsule machine (e.g. Keurig/Nespresso), P...           Medium
# 862                                            Espresso  Somewhat strong
# 2758                                          Pour over   Somewhat light
# 3097                                Espresso, Pour over  Somewhat strong
# 1329                                Pour over, Espresso   Somewhat light
# 3320                                Pour over, Espresso           Medium
# 3593                            Pour over, French press  Somewhat strong
#
#      How Much Caffeine?                                                Why  \
# 1321      Full caffeine  It tastes good, I need the caffeine, I need th...
# 2845      Full caffeine                  It tastes good, I need the ritual
# 1596          Half caff                  It tastes good, I need the ritual
# 380       Full caffeine                I need the caffeine, It tastes good
# 862       Full caffeine                              Other, It tastes good
# 2758      Full caffeine  It tastes good, I need the caffeine, I need th...
# 3097      Full caffeine                                     It tastes good
# 1329      Full caffeine                  I need the ritual, It tastes good
# 3320      Full caffeine  It tastes good, I need the caffeine, I need th...
# 3593      Full caffeine                I need the caffeine, It tastes good
#
#             Favorite Form
# 1321  Regular drip coffee
# 2845           Cappuccino
# 1596           Cappuccino
# 380              Pourover
# 862            Cappuccino
# 2758             Pourover
# 3097             Espresso
# 1329             Pourover
# 3320              Cortado
# 3593            Americano
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3207 entries, 34 to 4041
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 3207 non-null   object
#  1   WFH                 3207 non-null   object
#  2   Cups Per Day        3207 non-null   int64
#  3   Brew Methods        3207 non-null   object
#  4   Strength?           3207 non-null   object
#  5   How Much Caffeine?  3207 non-null   object
#  6   Why                 3207 non-null   object
#  7   Favorite Form       3207 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 225.5+ KB
# None

# %%
display(wfh_nona_df.sample(10))
display(wfh_nona_df.info())
# Out:
#                   Age                         WFH  Cups Per Day  \
# 118   25-34 years old  I primarily work in person             2
# 3057  45-54 years old          I do a mix of both             1
# 3858  25-34 years old          I do a mix of both             1
# 2578  25-34 years old  I primarily work in person             1
# 1137  35-44 years old  I primarily work in person             2
# 3630  35-44 years old  I primarily work from home             2
# 2401  25-34 years old          I do a mix of both             2
# 3524  25-34 years old          I do a mix of both             1
# 3795  25-34 years old  I primarily work from home             2
# 2608  25-34 years old  I primarily work from home             2
#
#                                            Brew Methods        Strength?  \
# 118                                 Pour over, Espresso           Medium
# 3057  Espresso, Pod/capsule machine (e.g. Keurig/Nes...           Medium
# 3858                                   Pour over, Other           Medium
# 2578                                              Other  Somewhat strong
# 1137  Coffee brewing machine (e.g. Mr. Coffee), Pour...  Somewhat strong
# 3630  French press, Espresso, Coffee brewing machine...  Somewhat strong
# 2401  Pour over, Espresso, Instant coffee, Bean-to-c...  Somewhat strong
# 3524  Pour over, Espresso, Pod/capsule machine (e.g....  Somewhat strong
# 3795                                          Pour over           Medium
# 2608                  Cold brew, Espresso, French press      Very strong
#
#      How Much Caffeine?                                                Why  \
# 118       Full caffeine                                  I need the ritual
# 3057      Full caffeine             I need the caffeine, I need the ritual
# 3858      Full caffeine                  It tastes good, I need the ritual
# 2578      Full caffeine                It tastes good, I need the caffeine
# 1137      Full caffeine  It tastes good, I need the caffeine, I need th...
# 3630      Full caffeine  It tastes good, I need the caffeine, I need th...
# 2401      Full caffeine  I need the caffeine, It tastes good, It makes ...
# 3524      Full caffeine                It tastes good, I need the caffeine
# 3795      Full caffeine                  It tastes good, I need the ritual
# 2608      Full caffeine  It tastes good, I need the caffeine, It makes ...
#
#      Favorite Form
# 118       Pourover
# 3057         Latte
# 3858      Pourover
# 2578       Cortado
# 1137      Pourover
# 3630         Latte
# 2401      Pourover
# 3524      Pourover
# 3795      Pourover
# 2608     Americano
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3207 entries, 34 to 4041
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 3207 non-null   object
#  1   WFH                 3207 non-null   object
#  2   Cups Per Day        3207 non-null   int64
#  3   Brew Methods        3207 non-null   object
#  4   Strength?           3207 non-null   object
#  5   How Much Caffeine?  3207 non-null   object
#  6   Why                 3207 non-null   object
#  7   Favorite Form       3207 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 225.5+ KB
# None

# %%
#Categories are <18 (0), 18-24 (18), 25-34 (25), 35-44 (35), 45-54 (45), 55-64 (55), 65< (65)

wfh_nona_df['Age'] = wfh_nona_df['Age'].str.replace('<18 years old', '0')
wfh_nona_df['Age'] = wfh_nona_df['Age'].str.replace('18-24 years old', '18')
wfh_nona_df['Age'] = wfh_nona_df['Age'].str.replace('25-34 years old', '25')
wfh_nona_df['Age'] = wfh_nona_df['Age'].str.replace('35-44 years old', '35')
wfh_nona_df['Age'] = wfh_nona_df['Age'].str.replace('45-54 years old', '45')
wfh_nona_df['Age'] = wfh_nona_df['Age'].str.replace('55-64 years old', '55')
wfh_nona_df['Age'] = wfh_nona_df['Age'].str.replace('>65 years old', '65')

# %%
wfh_nona_df.sample(10)
# Out:
#      Age                         WFH  Cups Per Day  \
# 1026  35  I primarily work from home             2
# 3483  25          I do a mix of both             1
# 1221  25  I primarily work in person             3
# 2965  25          I do a mix of both             2
# 2474  35          I do a mix of both             2
# 2098  25  I primarily work from home             3
# 116   25          I do a mix of both             0
# 537   25          I do a mix of both             2
# 101   25  I primarily work in person             2
# 3584  25  I primarily work from home             1
#
#                                            Brew Methods        Strength?  \
# 1026                                          Pour over  Somewhat strong
# 3483                                Espresso, Pour over      Very strong
# 1221  Pod/capsule machine (e.g. Keurig/Nespresso), E...  Somewhat strong
# 2965                                              Other  Somewhat strong
# 2474                                          Pour over           Medium
# 2098                                           Espresso  Somewhat strong
# 116                                           Pour over             Weak
# 537                                 Pour over, Espresso  Somewhat strong
# 101                      Pour over, Espresso, Cold brew   Somewhat light
# 3584  Pour over, French press, Pod/capsule machine (...  Somewhat strong
#
#      How Much Caffeine?                                                Why  \
# 1026      Full caffeine                  It tastes good, I need the ritual
# 3483      Full caffeine  It tastes good, I need the caffeine, I need th...
# 1221      Full caffeine                It tastes good, I need the caffeine
# 2965      Full caffeine                                     It tastes good
# 2474      Full caffeine                              It tastes good, Other
# 2098      Full caffeine                  It tastes good, I need the ritual
# 116               Decaf                                     It tastes good
# 537       Full caffeine  It tastes good, I need the caffeine, I need th...
# 101       Full caffeine                  It tastes good, I need the ritual
# 3584      Full caffeine                                     It tastes good
#
#             Favorite Form
# 1026            Americano
# 3483             Pourover
# 1221             Espresso
# 2965                Latte
# 2474             Pourover
# 2098                Latte
# 116                 Latte
# 537   Regular drip coffee
# 101              Pourover
# 3584             Pourover

# %%
wfh_nona_df['Age'] = pd.to_numeric(wfh_nona_df['Age'], errors='raise')

wfh_nona_df = wfh_nona_df.dropna()

display(wfh_nona_df.sample(10))
display(wfh_nona_df.info())
# Out:
#       Age                         WFH  Cups Per Day  \
# 3931   45  I primarily work in person             5
# 2266   25          I do a mix of both             2
# 2786   25  I primarily work from home             1
# 3016   25  I primarily work in person             2
# 1389   35          I do a mix of both             2
# 448    25  I primarily work from home             3
# 2894   25          I do a mix of both             0
# 1784   25  I primarily work from home             1
# 3719   35          I do a mix of both             2
# 1058   18          I do a mix of both             2
#
#                                            Brew Methods        Strength?  \
# 3931  Pour over, Coffee brewing machine (e.g. Mr. Co...  Somewhat strong
# 2266                                          Pour over  Somewhat strong
# 2786                                           Espresso  Somewhat strong
# 3016  Coffee brewing machine (e.g. Mr. Coffee), Othe...  Somewhat strong
# 1389                  Pour over, French press, Espresso      Very strong
# 448   Pour over, French press, Coffee brewing machin...      Very strong
# 2894  French press, Coffee brewing machine (e.g. Mr....  Somewhat strong
# 1784                                          Pour over           Medium
# 3719                                       French press      Very strong
# 1058                                Pour over, Espresso  Somewhat strong
#
#      How Much Caffeine?                                                Why  \
# 3931      Full caffeine                                     It tastes good
# 2266      Full caffeine                It tastes good, I need the caffeine
# 2786              Decaf                                     It tastes good
# 3016      Full caffeine  It tastes good, I need the caffeine, I need th...
# 1389      Full caffeine                It tastes good, I need the caffeine
# 448       Full caffeine  It tastes good, I need the caffeine, I need th...
# 2894          Half caff  It tastes good, I need the caffeine, I need th...
# 1784      Full caffeine  I need the ritual, It tastes good, I need the ...
# 3719      Full caffeine                It tastes good, I need the caffeine
# 1058      Full caffeine                                     It tastes good
#
#             Favorite Form
# 3931            Americano
# 2266              Cortado
# 2786                Latte
# 3016  Regular drip coffee
# 1389           Cappuccino
# 448              Pourover
# 2894  Regular drip coffee
# 1784             Pourover
# 3719             Pourover
# 1058           Cappuccino
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3207 entries, 34 to 4041
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 3207 non-null   int64
#  1   WFH                 3207 non-null   object
#  2   Cups Per Day        3207 non-null   int64
#  3   Brew Methods        3207 non-null   object
#  4   Strength?           3207 non-null   object
#  5   How Much Caffeine?  3207 non-null   object
#  6   Why                 3207 non-null   object
#  7   Favorite Form       3207 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 225.5+ KB
# None
